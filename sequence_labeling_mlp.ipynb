# %% [markdown]
# <a href="https://colab.research.google.com/github/sabujcb/Mycodes/blob/main/sequence_labeling_mlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sequence labeling (POS tagging) with MLP
#
# This notebook builds upon the [classification with MLP notebook](https://github.com/TurkuNLP/intro-to-nlp/blob/master/mlp_imdb_hf_dset_and_trainer.ipynb) and shows how to implement a basic sequence labeling method.

# %% [markdown]
# ---
#
# # Setup
#
# Install the required Python packages using [pip](https://en.wikipedia.org/wiki/Pip):
#
# * [`transformers`](https://huggingface.co/docs/transformers/index) is a popular deep learning package primarily on top of torch
# * [`datasets`](https://huggingface.co/docs/datasets/) provides support for loading, creating, and manipulating datasets
# * [`evaluate`](https://huggingface.co/docs/evaluate/index) is a library of performance metrics (like accuracy etc)

# %%
# !pip3 install --upgrade transformers[torch]
# !pip3 install -q evaluate
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Collecting transformers[torch]
#   Downloading transformers-5.5.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (4.67.3)
# Requirement already satisfied: torch>=2.4 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.10.0+cpu)
# Requirement already satisfied: accelerate>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (1.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->transformers[torch]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->transformers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->transformers[torch]) (3.1.6)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[torch]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[torch]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[torch]) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers[torch]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers[torch]) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4->transformers[torch]) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers[torch]) (0.1.2)
# Downloading transformers-5.5.1-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 34.8 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed transformers-5.5.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.5 MB/s eta 0:00:00

# %%
import datasets
import evaluate
import transformers

# %% [markdown]
# ---
#
# # Get and prepare data
#
# *   Let us work with the venerable, if somewhat dated [CoNLL'03 shared task](https://aclanthology.org/W03-0419.pdf) English data
# *   These are English news articles, and have annotation for POS, syntactic chunks, and named entities (in the IOB format)
#
# The data as originally distributed for the 2003 shared task has the following format:
#
# ```
# Only RB B-NP O
# France NNP I-NP B-LOC
# and CC I-NP O
# Britain NNP I-NP B-LOC
# backed VBD B-VP O
# Fischler NNP B-NP B-PER
# 's POS I-NP O
# proposal NN I-NP O
# . . O O
# ```
#
# Here, the four space-separated columns are token text, POS tag, chunk tag, and NER tag. The goal of the original task is to predict the NER tags using the other information as features, but the dataset can be used to study predicting the other columns too.
#
# The dataset happens to be in the HF datasets collection, so we can grab it from there

# %%
import torch
import transformers
import datasets

from pprint import pprint    # pretty-print

dataset = datasets.load_dataset("dany0407/conll2003")

print(dataset)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/1.22M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/310k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/281k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/3453 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 14041
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3250
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3453
#     })
# })

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# As you can see above, the various labels (POS, NER and chunk tags) are converted into IDs in this dataset. We can access the textual labels of these tags through the dataset `features`:

# %%
POS_TAG_NAMES = dataset['train'].features['pos_tags'].feature.names
NER_TAG_NAMES = dataset['train'].features['ner_tags'].feature.names
CHUNK_TAG_NAMES = dataset['train'].features['chunk_tags'].feature.names

# %% [markdown]
# We can then create mappings from names to IDs and back as Python dictionaries:

# %%
POS2ID = { n: i for i, n in enumerate(POS_TAG_NAMES) }
ID2POS = { i: n for i, n in enumerate(POS_TAG_NAMES) }

NER2ID = { n: i for i, n in enumerate(NER_TAG_NAMES) }
ID2NER = { i: n for i, n in enumerate(NER_TAG_NAMES) }

CHUNK2ID = { n: i for i, n in enumerate(CHUNK_TAG_NAMES) }
ID2CHUNK = { i: n for i, n in enumerate(CHUNK_TAG_NAMES) }

# %% [markdown]
# This is what these mappings look like:

# %%
print(NER2ID)
# Out:
# {'O': 0, 'B-PER': 1, 'I-PER': 2, 'B-ORG': 3, 'I-ORG': 4, 'B-LOC': 5, 'I-LOC': 6, 'B-MISC': 7, 'I-MISC': 8}

# %%
print(ID2NER)
# Out:
# {0: 'O', 1: 'B-PER', 2: 'I-PER', 3: 'B-ORG', 4: 'I-ORG', 5: 'B-LOC', 6: 'I-LOC', 7: 'B-MISC', 8: 'I-MISC'}

# %% [markdown]
# Let's also add in explanations from Penn Treebank for the POS tags:

# %%
# From the documentation page and from here https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

POS2DESCRIPTION = {
    "CC": "Coordinating conjunction",
    "CD": "Cardinal number",
    "DT": "Determiner",
    "EX": "Existential there",
    "FW": "Foreign word",
    "IN": "Preposition or subordinating conjunction",
    "JJ": "Adjective",
    "JJR": "Adjective, comparative",
    "JJS": "Adjective, superlative",
    "LS": "List item marker",
    "MD": "Modal",
    "NN": "Noun, singular or mass",
    "NNS": "Noun, plural",
    "NNP": "Proper noun, singular",
    "NNPS": "Proper noun, plural",
    "PDT": "Predeterminer",
    "POS": "Possessive ending",
    "PRP": "Personal pronoun",
    "PRP$": "Possessive pronoun",
    "RB": "Adverb",
    "RBR": "Adverb, comparative",
    "RBS": "Adverb, superlative",
    "RP": "Particle",
    "SYM": "Symbol",
    "TO": "to",
    "UH": "Interjection",
    "VB": "Verb, base form",
    "VBD": "Verb, past tense",
    "VBG": "Verb, gerund or present participle",
    "VBN": "Verb, past participle",
    "VBP": "Verb, non-3rd person singular present",
    "VBZ": "Verb, 3rd person singular present",
    "WDT": "Wh-determiner",
    "WP": "Wh-pronoun",
    "WP$": "Possessive wh-pronoun",
    "WRB": "Wh-adverb"
}

# %% [markdown]
# We can now try to make sense of the tags:

# %%
import tabulate

e = dataset["train"][12]    # work on the same example

table = []
for token, pos_id, chunk_id, ner_id in zip(e["tokens"], e["pos_tags"], e["chunk_tags"], e["ner_tags"]):
    ner_tag = ID2NER[ner_id]
    chunk_tag = ID2CHUNK[chunk_id]
    pos_tag = ID2POS[pos_id]
    pos_def = POS2DESCRIPTION.get(pos_tag,pos_tag)
    table.append([token, ner_tag, chunk_tag, pos_tag, pos_def])

print(tabulate.tabulate(table,headers=["Token", "NER", "Chunk", "POS", "POS definition"]))
# Out:
# Token     NER    Chunk    POS    POS definition
# --------  -----  -------  -----  ------------------------
# Only      O      B-NP     RB     Adverb
# France    B-LOC  I-NP     NNP    Proper noun, singular
# and       O      I-NP     CC     Coordinating conjunction
# Britain   B-LOC  I-NP     NNP    Proper noun, singular
# backed    O      B-VP     VBD    Verb, past tense
# Fischler  B-PER  B-NP     NNP    Proper noun, singular
# 's        O      B-NP     POS    Possessive ending
# proposal  O      I-NP     NN     Noun, singular or mass
# .         O      O        .      .

# %% [markdown]
# Note that the data is organized into sentences.

# %% [markdown]
# ---
#
# # Create features
#
# We'll define a simple function that takes a token sequence, the index of the focus token, and a window size and generates a few basic explicit features relevant to the task.
#
# (Note that as we'll be predicting the POS tag, we won't look at the chunk or NER tags, which would typically only be predicted _after_ predicting POS in a "traditional" NLP pipeline)

# %%
def token_features(tokens, index, window_size):
    # Generate features for token in position `index` in given list of tokens
    features = []

    # Context window start and end
    window_start = max(0, index-window_size)
    window_end = min(index+window_size+1, len(tokens))    # note +1 for range

    for i in range(window_start, window_end):
          offset = i - index    # relative position
          if offset == 0:     # change if necessary  just toggling around
             features.append(f"token[{offset}]={tokens[i]}")

    # Example custom feature: does focus token start with an upper-case letter?
    if tokens[index][0].isupper():
        features.append("first-letter-capitalized")

    return features

# %% [markdown]
# We can call this function for all tokens in a sentence like so:

# %%
def add_features_to_sentence(sentence):
    # Collect lists of features for all tokens here
    all_features = []

    tokens = sentence["tokens"]
    for index in range(len(tokens)):
        all_features.append(" ".join(token_features(tokens, index, window_size=3)))

    return { "features": all_features}

# %%
for feats in add_features_to_sentence(dataset["train"][12])["features"]:
    print(feats)
# Out:
# token[0]=Only first-letter-capitalized
# token[0]=France first-letter-capitalized
# token[0]=and
# token[0]=Britain first-letter-capitalized
# token[0]=backed
# token[0]=Fischler first-letter-capitalized
# token[0]='s
# token[0]=proposal
# token[0]=.

# %% [markdown]
# The dataset is organized into sentences, so we can use the above function to add features to the entire dataset as follows.
#
# **Note**: unlike e.g. the Python`map` function, [`Dataset.map`](https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.map) function _updates_ its argument dataset, keeping existing values.

# %%
dataset = dataset.map(add_features_to_sentence)
# Out:
# Map:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3453 [00:00<?, ? examples/s]

# %% [markdown]
# Let's check that one more time:

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'features': ['token[0]=Only first-letter-capitalized',
#               'token[0]=France first-letter-capitalized',
#               'token[0]=and',
#               'token[0]=Britain first-letter-capitalized',
#               'token[0]=backed',
#               'token[0]=Fischler first-letter-capitalized',
#               "token[0]='s",
#               'token[0]=proposal',
#               'token[0]=.'],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# ---
#
# # Flatten dataset
#
# The MLP code that we introduced previously expects each of the `train`, `validation` and `test` subsets of the data to consist of simple sequences of examples.
#
# Now that we have run the feature generation, we no longer need the sentence structure and can "flatten" the data, i.e. remove the "sentence" level of granularity.

# %%
def flatten(subset):
    # Keys for values to flatten
    keys = ["tokens", "pos_tags", "chunk_tags", "ner_tags", "features"]

    # Initialize to empty lists of tokens etc.
    flattened = { k: [] for k in keys }

    # Concatenate per-sentence lists of tokens etc.
    for sentence in subset:
        for key in keys:
            flattened[key].extend(sentence[key])

    # Return as Dataset object
    return datasets.Dataset.from_dict(flattened)

# %% [markdown]
# Call `flatten` for each of the subsets and make a new `DatasetDict` containing the flattened subsets:

# %%
flattened_dict = {
    "train": flatten(dataset["train"]),
    "validation": flatten(dataset["validation"]),
    "test": flatten(dataset["test"]),
}

flat_dataset = datasets.DatasetDict(flattened_dict)

# %% [markdown]
# Check that the new dataset looks OK:

# %%
flat_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 203621
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 51362
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 46435
#     })
# })

# %%
for i in range(10):
    token = flat_dataset["train"]["tokens"][i]
    pos_tag = ID2POS[flat_dataset["train"]["pos_tags"][i]]
    description = POS2DESCRIPTION.get(pos_tag, pos_tag)
    features = flat_dataset["train"]["features"][i]
    print(f"{token}\t{pos_tag}\t{description}\t{features}")
# Out:
# EU	NNP	Proper noun, singular	token[0]=EU first-letter-capitalized
# rejects	VBZ	Verb, 3rd person singular present	token[0]=rejects
# German	JJ	Adjective	token[0]=German first-letter-capitalized
# call	NN	Noun, singular or mass	token[0]=call
# to	TO	to	token[0]=to
# boycott	VB	Verb, base form	token[0]=boycott
# British	JJ	Adjective	token[0]=British first-letter-capitalized
# lamb	NN	Noun, singular or mass	token[0]=lamb
# .	.	.	token[0]=.
# Peter	NNP	Proper noun, singular	token[0]=Peter first-letter-capitalized

# %% [markdown]
# Note that this is now a single long dataset of tokens without sentence boundaries.

# %% [markdown]
# # Tokenization
#
# Tokenization needs a bit of thinking, so that we can keep things as simple as possible. We need to turn the strings of features into tokens so that we can then plug them into our MLP.
#
# This would be perfectly doable with the standard tokenizer if only we could convince it to simply tokenize on whitespace and leave everything else untouched.
#
# We cannot use the approach from the MLP lecture, because the pretrained tokenizers tend to modify the data in various ways. We need more control, i.e. we need to make our own tokenizer. Luckily, this is easier than it sounds.

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import WhitespaceSplit
from transformers import PreTrainedTokenizerFast

def build_whitespace_tokenizer(dataset, vocab_size=None, min_frequency=2):
    tokenizer = Tokenizer(WordLevel(unk_token="[UNK]"))

    # Use pure whitespace splitting, no normalization or subwording
    tokenizer.normalizer = None #This is a step which happens before tokenization, we want nothing done. So setting to None.
    tokenizer.pre_tokenizer = WhitespaceSplit() #This is a pre-tokenization step, we want to strictly only use whitespace.

    # List [PAD] first, so it gets index 0
    special_tokens = ["[PAD]","[UNK]"]

    # WordLevelTrainer builds a word-level tokenizer, i.e. no subwords are used, no BPE algorithm, simply full words
    # Words that do not fit into the vocabulary will be replaced by [UNK], which is fine for our purposes
    trainer = WordLevelTrainer(
        vocab_size=vocab_size,
        min_frequency=min_frequency, #only consider tokens which appear this many times
        special_tokens=special_tokens,
    )
    # This is where the actual training happens
    iterator = (example["features"] for example in dataset)
    tokenizer.train_from_iterator(iterator, trainer=trainer)
    print(tokenizer)

    # And this then turns the tokenizer into something we can use
    hf_tokenizer = PreTrainedTokenizerFast(
        tokenizer_object=tokenizer,

        unk_token="[UNK]",
        pad_token="[PAD]",
    )

    return hf_tokenizer
tokenizer = build_whitespace_tokenizer(flat_dataset["train"], vocab_size=15000)
# Out:
# Tokenizer(version="1.0", truncation=None, padding=None, added_tokens=[{"id":0, "content":"[PAD]", "single_word":False, "lstrip":False, "rstrip":False, ...}, {"id":1, "content":"[UNK]", "single_word":False, "lstrip":False, "rstrip":False, ...}], normalizer=None, pre_tokenizer=WhitespaceSplit(), post_processor=None, decoder=None, model=WordLevel(vocab={"[PAD]":0, "[UNK]":1, "first-letter-capitalized":2, "token[0]=.":3, "token[0]=,":4, ...}, unk_token="[UNK]"))

# %%
tokenizer.vocab
# Out:
# {'token[0]=58': 916,
#  'token[0]=scarce': 11605,
#  'token[0]=1996-08-30': 2483,
#  'token[0]=Takeishi': 7172,
#  'token[0]=anything': 1725,
#  'token[0]=several': 475,
#  'token[0]=short': 711,
#  'token[0]=Ato': 6434,
#  'token[0]=PDI': 9904,
#  'token[0]=trying': 733,
#  'token[0]=Medellin': 9728,
#  'token[0]=George': 1312,
#  'token[0]=DHA': 9082,
#  'token[0]=Warsaw': 2153,
#  'token[0]=ERA': 9157,
#  'token[0]=benefits': 7330,
#  'token[0]=Ford': 1950,
#  'token[0]=lounge': 11214,
#  'token[0]=boy': 1613,
#  'token[0]=near': 417,
#  'token[0]=circulation': 10696,
#  'token[0]=Gajdos': 2296,
#  'token[0]=Yugoslav': 1993,
#  'token[0]=Hospital': 1818,
#  'token[0]=Gounon': 6707,
#  'token[0]=CBI': 6500,
#  'token[0]=restrict': 11560,
#  'token[0]=1230': 8262,
#  'token[0]=risk': 1284,
#  'token[0]=Liberec': 9618,
#  'token[0]=Kerametal': 9543,
#  'token[0]=Cosenza': 9052,
#  'token[0]=Moura': 3761,
#  'token[0]=Workers': 2601,
#  'token[0]=gained': 2192,
#  'token[0]=SoCal': 10210,
#  'token[0]=Camerlengo': 6517,
#  'token[0]=forehand': 10993,
#  'token[0]=products': 1209,
#  'token[0]=CEO': 8948,
#  'token[0]=reiterated': 7889,
#  'token[0]=prayers': 3467,
#  'token[0]=cancellation': 7363,
#  'token[0]=70th': 3583,
#  'token[0]=1.50': 8205,
#  'token[0]=long': 664,
#  'token[0]=dissolution': 7491,
#  'token[0]=2.1': 4977,
#  'token[0]=Development': 5179,
#  'token[0]=Dominic': 9131,
#  'token[0]=Hock': 6756,
#  'token[0]=also': 82,
#  'token[0]=Slams': 10204,
#  'token[0]=Jacek': 9479,
#  'token[0]=critic': 7440,
#  'token[0]=American-style': 8770,
#  'token[0]=exclusive': 4653,
#  'token[0]=192': 8331,
#  'token[0]=undisclosed': 11871,
#  'token[0]=FRANCISCO': 966,
#  'token[0]=gives': 4681,
#  'token[0]=Habsudova': 3206,
#  'token[0]=decrees': 10808,
#  'token[0]=Bernhard': 8881,
#  'token[0]=population': 2693,
#  'token[0]=ammunition': 5647,
#  'token[0]=Rudar': 10078,
#  'token[0]=Cronulla': 9062,
#  'token[0]=Appeals': 8785,
#  'token[0]=outperform': 4050,
#  'token[0]=AUGUST': 1062,
#  'token[0]=comparison': 10736,
#  'token[0]=Henman': 4344,
#  'token[0]=travelling': 2742,
#  'token[0]=DUBAI': 4282,
#  'token[0]=Eletropaulo': 6624,
#  'token[0]=plays': 3049,
#  'token[0]=Shimaponda': 10171,
#  'token[0]=VW': 5594,
#  'token[0]=debt': 1341,
#  'token[0]=Yasushi': 10461,
#  'token[0]=New': 103,
#  'token[0]=.527': 4154,
#  'token[0]=Edberg': 2830,
#  'token[0]=proposal': 2442,
#  'token[0]=Premier': 4460,
#  'token[0]=Predrosa': 9982,
#  'token[0]=democratic': 3372,
#  'token[0]=concept': 10744,
#  'token[0]=Hamilton': 4335,
#  'token[0]=Borsuk': 6475,
#  'token[0]=blaze': 7339,
#  'token[0]=Rugby': 4476,
#  'token[0]=BRATISLAVA': 6446,
#  'token[0]=demand': 466,
#  'token[0]=surplus': 2240,
#  'token[0]=foreign': 287,
#  'token[0]=Indonesia': 1017,
#  'token[0]=Pudvah': 10001,
#  'token[0]=Florida': 1309,
#  'token[0]=grandparents': 11031,
#  'token[0]=repeat': 4084,
#  'token[0]=administrative': 3875,
#  'token[0]=Hidemichi': 5262,
#  'token[0]=Tanaka': 7174,
#  'token[0]=Did': 2520,
#  'token[0]=assistant': 4566,
#  'token[0]=Manhattan': 6896,
#  'token[0]=FOR': 920,
#  'token[0]=Investigation': 9465,
#  'token[0]=debut': 2012,
#  'token[0]=showdown': 7951,
#  'token[0]=food': 1144,
#  'token[0]=Odnosum': 5431,
#  'token[0]=Airport': 5050,
#  'token[0]=2,383': 8356,
#  'token[0]=13.': 2755,
#  'token[0]=standard': 6089,
#  'token[0]=metres': 244,
#  'token[0]=Owen-Jones': 9894,
#  'token[0]=H1': 2534,
#  'token[0]=measles': 5917,
#  'token[0]=Seve': 10153,
#  'token[0]=doubts': 5772,
#  'token[0]=Nastase': 9805,
#  'token[0]=replying': 11548,
#  'token[0]=Verona': 7206,
#  'token[0]=Dole': 490,
#  'token[0]=.423': 8142,
#  'token[0]=Des': 6590,
#  'token[0]=test': 537,
#  'token[0]=Barbara': 2793,
#  'token[0]=Simitis': 2913,
#  'token[0]=Jay': 6802,
#  'token[0]=+2': 6186,
#  'token[0]=vacancy': 11901,
#  'token[0]=luxury': 11220,
#  'token[0]=Heath': 9391,
#  'token[0]=Capital': 2805,
#  'token[0]=plainclothes': 11394,
#  'token[0]=Minnesota': 1965,
#  'token[0]=DENOMS': 9081,
#  'token[0]=contrary': 10773,
#  'token[0]=host': 5864,
#  'token[0]=yield': 4148,
#  'token[0]=fugitive': 11012,
#  'token[0]=journalists': 3430,
#  'token[0]=engineer': 10920,
#  'token[0]=signals': 11655,
#  'token[0]=anybody': 10553,
#  'token[0]=Pay': 5451,
#  'token[0]=Silke': 10191,
#  'token[0]=fielding': 10967,
#  'token[0]=signature': 11656,
#  'token[0]=minister': 401,
#  'token[0]=elderly': 5779,
#  'token[0]=percent': 65,
#  'token[0]=Amman': 1570,
#  'token[0]=Corretja': 6557,
#  'token[0]=Mrs.': 6937,
#  'token[0]=Muller': 9767,
#  'token[0]=not': 39,
#  'token[0]=Ed': 9170,
#  'token[0]=form': 1444,
#  'token[0]=IRISH': 9447,
#  'token[0]=phase': 4053,
#  'token[0]=CZK': 6514,
#  'token[0]=Dekker': 5176,
#  'token[0]=852': 4197,
#  'token[0]=girlfriend': 7605,
#  'token[0]=autumn': 4571,
#  'token[0]=noted': 1759,
#  'token[0]=CYCLING': 1685,
#  'token[0]=Miladin': 9737,
#  'token[0]=guilder': 11040,
#  'token[0]=Democracy': 2824,
#  'token[0]=behind': 387,
#  'token[0]=37': 2260,
#  'token[0]=balanced': 10593,
#  'token[0]=factors': 3389,
#  'token[0]=reflected': 7883,
#  'token[0]=practice': 11415,
#  'token[0]=flag': 7582,
#  'token[0]=Canberra': 3633,
#  'token[0]=brand': 10634,
#  'token[0]=convent': 10776,
#  'token[0]=pullout': 4796,
#  'token[0]=leading': 561,
#  'token[0]=unite': 6151,
#  'token[0]=mutual': 4736,
#  'token[0]=cannons': 10663,
#  'token[0]=appearance': 4559,
#  'token[0]=Johnstone': 6815,
#  'token[0]=given': 707,
#  'token[0]=11th': 1792,
#  'token[0]=FFK': 6642,
#  'token[0]=225-5': 8405,
#  'token[0]=stored': 7990,
#  'token[0]=Valle': 10381,
#  'token[0]=high': 624,
#  'token[0]=Motherwell': 6931,
#  'token[0]=comics': 5723,
#  'token[0]=Jesus': 6808,
#  'token[0]=birdied': 10612,
#  'token[0]=JOURNAL': 5286,
#  'token[0]=secure': 4100,
#  'token[0]=42.5': 8546,
#  'token[0]=Kimiko': 3722,
#  'token[0]=Vialle': 7208,
#  'token[0]=RAMALLAH': 7029,
#  'token[0]=heard': 2193,
#  'token[0]=During': 5187,
#  'token[0]=Hearts': 4341,
#  'token[0]=Pioline': 3255,
#  'token[0]=2-1': 914,
#  'token[0]=ringing': 11574,
#  'token[0]=Dubnica': 9141,
#  'token[0]=30-year': 8470,
#  'token[0]=Aides': 8745,
#  'token[0]=Soviet': 1843,
#  'token[0]=install': 11135,
#  'token[0]=late': 416,
#  'token[0]=militant': 5921,
#  'token[0]=NBH': 4418,
#  'token[0]=Togliatti': 10327,
#  'token[0]=Ames': 5058,
#  'token[0]=affairs': 3322,
#  'token[0]=platform': 4778,
#  'token[0]=rankings': 4805,
#  'token[0]=hurt': 2419,
#  'token[0]=Candiotti': 8970,
#  'token[0]=congress': 4610,
#  'token[0]=unknown': 3104,
#  'token[0]=announcing': 7290,
#  'token[0]=Specter': 4495,
#  'token[0]=Raoux': 7039,
#  'token[0]=ranging': 7869,
#  'token[0]=+301': 3114,
#  'token[0]=one-week': 11323,
#  'token[0]=Kazakhstan': 9539,
#  'token[0]=Hekmatyar': 5258,
#  'token[0]=helicopters': 5856,
#  'token[0]=singled': 6069,
#  'token[0]=approach': 4561,
#  'token[0]=Authorities': 6437,
#  'token[0]=274': 8435,
#  'token[0]=502': 8593,
#  'token[0]=serving': 3082,
#  'token[0]=LOT': 9589,
#  'token[0]=jumps': 11166,
#  'token[0]=Republika': 7050,
#  'token[0]=Buducnost': 5107,
#  'token[0]=Ferrigato': 4305,
#  'token[0]=Belgrade': 3617,
#  'token[0]=Romesh': 10069,
#  'token[0]=murder': 1357,
#  'token[0]=submitted': 6103,
#  'token[0]=1983': 6266,
#  'token[0]=Radstrom': 10029,
#  'token[0]=TIRANA': 4504,
#  'token[0]=weighted': 11947,
#  'token[0]=Oxford': 2564,
#  'token[0]=Gul': 9350,
#  'token[0]=Natural': 9806,
#  'token[0]=Gianluca': 4324,
#  'token[0]=Olomouc': 9868,
#  'token[0]=vital': 11925,
#  'token[0]=around': 260,
#  'token[0]=systematically': 11776,
#  'token[0]=teacup': 11783,
#  'token[0]=interrupted': 11147,
#  'token[0]=extradite': 7556,
#  'token[0]=16-17': 8305,
#  'token[0]=commanders': 7399,
#  'token[0]=WELLINGTON': 2597,
#  'token[0]=NEC': 1831,
#  'token[0]=post-match': 11411,
#  'token[0]=focused': 5824,
#  'token[0]=sauce': 7924,
#  'token[0]=Cal': 5121,
#  'token[0]=1nb': 6267,
#  'token[0]=IS': 9448,
#  'token[0]=months': 390,
#  'token[0]=attempting': 7310,
#  'token[0]=measuring': 7723,
#  'token[0]=Monterrey': 9753,
#  'token[0]=Medical': 1827,
#  'token[0]=10-year': 4941,
#  'token[0]=soared': 11687,
#  'token[0]=100.6': 8224,
#  'token[0]=93': 4203,
#  'token[0]=becoming': 3896,
#  'token[0]=podium': 7819,
#  'token[0]=1940': 6260,
#  'token[0]=Ebe': 9167,
#  'token[0]=balls': 3338,
#  'token[0]=RUN': 5473,
#  'token[0]=uncertainty': 8072,
#  'token[0]=conducting': 10747,
#  'token[0]=manufacturing': 7714,
#  'token[0]=shared': 4104,
#  'token[0]=mission': 1205,
#  'token[0]=riyal': 4826,
#  'token[0]=2.3': 8368,
#  'token[0]=elaborate': 5778,
#  'token[0]=AOL': 3589,
#  'token[0]=Angolan': 4222,
#  'token[0]=Carretero': 8982,
#  'token[0]=0.50': 4935,
#  'token[0]=militants': 2208,
#  'token[0]=weeks': 511,
#  'token[0]=Turkey': 771,
#  'token[0]=action': 802,
#  'token[0]=brokers': 3342,
#  'token[0]=Levenson': 6869,
#  'token[0]=indifference': 7652,
#  'token[0]=role': 1766,
#  'token[0]=decisive': 4625,
#  'token[0]=effort': 2398,
#  'token[0]=pounds': 1052,
#  'token[0]=faction': 2185,
#  'token[0]=OHIO': 9846,
#  'token[0]=DETROIT': 1171,
#  'token[0]=Ieng': 3704,
#  'token[0]=Its': 3216,
#  'token[0]=gone': 2656,
#  'token[0]=2nd': 4987,
#  'token[0]=skirmish': 11667,
#  'token[0]=fractured': 11003,
#  'token[0]=size': 4107,
#  'token[0]=Germany': 116,
#  'token[0]=firing': 3395,
#  'token[0]=hardly': 11055,
#  'token[0]=One': 800,
#  'token[0]=HCFA': 9361,
#  'token[0]=43.50': 8551,
#  'token[0]=55th': 8600,
#  'token[0]=themselves': 4131,
#  'token[0]=planes': 4776,
#  'token[0]=USDA': 1986,
#  'token[0]=Whittier': 7235,
#  'token[0]=shore': 7948,
#  'token[0]=flew': 2190,
#  'token[0]=Mieciel': 9736,
#  'token[0]=arrivals': 7305,
#  'token[0]=Lejeune': 6866,
#  'token[0]=Po': 7012,
#  'token[0]=435': 8555,
#  'token[0]=bombs': 10622,
#  'token[0]=0.05': 6205,
#  'token[0]=steadily': 11728,
#  'token[0]=abroad': 1719,
#  'token[0]=degree': 10814,
#  'token[0]=registrations': 2707,
#  'token[0]=Rocca': 3806,
#  'token[0]=10.00': 6219,
#  'token[0]=committee': 1088,
#  'token[0]=comeback': 10729,
#  'token[0]=9.': 611,
#  'token[0]=366': 8497,
#  'token[0]=Eva': 6636,
#  'token[0]=Fulcheri': 6673,
#  'token[0]=of': 6,
#  'token[0]=Ka': 9517,
#  'token[0]=FLORIDA': 1395,
#  'token[0]=pages': 11355,
#  'token[0]=Craiova': 9058,
#  'token[0]=55,000-B': 8599,
#  'token[0]=6-1': 269,
#  'token[0]=overpowered': 11345,
#  'token[0]=1996-08-23': 185,
#  'token[0]=ability': 7258,
#  'token[0]=establishing': 10933,
#  'token[0]=fueled': 11011,
#  'token[0]=explosive': 5797,
#  'token[0]=views': 6159,
#  'token[0]=LUMPUR': 5327,
#  'token[0]=Yastrzhembsky': 10460,
#  'token[0]=Results': 238,
#  'token[0]=closes': 3355,
#  'token[0]=overtake': 11350,
#  'token[0]=5-248': 8579,
#  'token[0]=pride': 11439,
#  'token[0]=originally': 5951,
#  'token[0]=Sachs': 4482,
#  'token[0]=seen': 628,
#  'token[0]=Zanoli': 10475,
#  'token[0]=Nijmegen': 2323,
#  'token[0]=Lomas': 5349,
#  'token[0]=Bedie': 4240,
#  'token[0]=Brazilian': 1122,
#  'token[0]=deaths': 7449,
#  'token[0]=MIAMI': 5361,
#  'token[0]=div': 4638,
#  'token[0]=McGrath': 3239,
#  'token[0]=calf': 10655,
#  'token[0]=Russian': 195,
#  'token[0]=60.00': 8616,
#  'token[0]=set': 248,
#  'token[0]=provisional': 11473,
#  'token[0]=Rep': 7048,
#  'token[0]=tells': 8024,
#  'token[0]=Sep': 10151,
#  'token[0]=Hawksworth': 9387,
#  'token[0]=clashes': 2172,
#  'token[0]=Dean': 3657,
#  'token[0]=wheelchair': 8111,
#  'token[0]=brilliant': 5693,
#  'token[0]=c': 572,
#  'token[0]=boosted': 3904,
#  'token[0]=Unitog': 10361,
#  'token[0]=political': 297,
#  'token[0]=basis': 1525,
#  'token[0]=Duesseldorf': 2827,
#  'token[0]=80': 1299,
#  'token[0]=1948': 4167,
#  'token[0]=study': 2462,
#  'token[0]=85,000': 8668,
#  'token[0]=Lanka': 595,
#  'token[0]=Pembroke': 7002,
#  'token[0]=photographer': 11384,
#  'token[0]=age': 3324,
#  'token[0]=Simian': 10195,
#  'token[0]=Hu': 9429,
#  'token[0]=washed': 6165,
#  'token[0]=Tour': 1848,
#  'token[0]=Wouden': 5620,
#  'token[0]=Southampton': 4494,
#  'token[0]=CDU': 2093,
#  'token[0]=Antonio': 2782,
#  'token[0]=Tillekeratne': 10320,
#  'token[0]=Acre': 6402,
#  'token[0]=scheme': 11610,
#  'token[0]=arable': 5654,
#  'token[0]=105': 4947,
#  'token[0]=Reneberg': 5479,
#  'token[0]=passport': 5962,
#  'token[0]=167': 6250,
#  'token[0]=manager': 665,
#  'token[0]=moving': 3448,
#  'token[0]=patent': 7796,
#  'token[0]=surrender': 4123,
#  'token[0]=inquiries': 11130,
#  'token[0]=guitar': 11041,
#  'token[0]=RKC': 2899,
#  'token[0]=ECOMOG': 6612,
#  'token[0]=constant': 10760,
#  'token[0]=disagreement': 10854,
#  'token[0]=tested': 4885,
#  'token[0]=unions': 2745,
#  'token[0]=Forsbrand': 6666,
#  'token[0]=liberal': 5898,
#  'token[0]=19.': 6258,
#  'token[0]=Major': 1240,
#  'token[0]=en': 7525,
#  'token[0]=6-0': 822,
#  'token[0]=beating': 3895,
#  'token[0]=blind': 5684,
#  'token[0]=born': 2168,
#  'token[0]=stressed': 11741,
#  'token[0]=initiative': 7657,
#  'token[0]=Gazeta': 4320,
#  'token[0]=yards': 4147,
#  'token[0]=any': 215,
#  'token[0]=slow': 2723,
#  'token[0]=vault': 8090,
#  'token[0]=Algerians': 8759,
#  'token[0]=organisations': 3453,
#  'token[0]=Sun': 3289,
#  'token[0]=Lazar': 9609,
#  'token[0]=Lauck': 1822,
#  'token[0]=Harvey': 6732,
#  'token[0]=Illingworth': 9453,
#  'token[0]=Helmut': 6740,
#  'token[0]=THOMSON': 10291,
#  'token[0]=frost': 4675,
#  'token[0]=Footscray': 5213,
#  'token[0]=pact': 1646,
#  'token[0]=Itamar': 9469,
#  'token[0]=Chesterfield': 4273,
#  'token[0]=2.03': 8367,
#  'token[0]=East': 584,
#  'token[0]=0900': 8192,
#  'token[0]=Dimitrios': 9119,
#  'token[0]=developments': 4633,
#  'token[0]=0.08': 6207,
#  'token[0]=prayer': 4784,
#  'token[0]=testing': 6123,
#  'token[0]=rib': 11571,
#  'token[0]=palace': 4758,
#  'token[0]=3-1': 1668,
#  'token[0]=Subaru': 3833,
#  'token[0]=something': 2060,
#  'token[0]=McNamara': 6916,
#  'token[0]=over': 72,
#  'token[0]=b-4': 10586,
#  'token[0]=AT': 128,
#  'token[0]=India': 259,
#  'token[0]=RESEARCH': 4465,
#  'token[0]=Jan': 1398,
#  'token[0]=overwhelmingly': 7785,
#  'token[0]=colonial': 10725,
#  'token[0]=154': 8300,
#  'token[0]=Arum': 8800,
#  'token[0]=Rating': 2130,
#  'token[0]=Mauritania': 9718,
#  'token[0]=coaches': 10709,
#  'token[0]=212': 1924,
#  'token[0]=15-30': 8293,
#  'token[0]=20.42': 8378,
#  'token[0]=A.G.': 8699,
#  'token[0]=apartheid-era': 7293,
#  'token[0]=malaria': 5907,
#  'token[0]=Bangkok': 4237,
#  'token[0]=Galina': 9304,
#  'token[0]=1/2': 241,
#  'token[0]=offset': 4044,
#  'token[0]=Paris': 636,
#  'token[0]=factions': 1742,
#  'token[0]=gunfire': 11042,
#  'token[0]=belted': 7329,
#  'token[0]=hurled': 11090,
#  'token[0]=Jimy': 9501,
#  'token[0]=Iraqi': 404,
#  'token[0]=hailed': 7614,
#  'token[0]=941': 4204,
#  'token[0]=goddess': 11027,
#  'token[0]=Greece': 1695,
#  'token[0]=futures': 1627,
#  'token[0]=13-year-old': 6233,
#  'token[0]=weekly': 2067,
#  'token[0]=curb': 10800,
#  'token[0]=her': 97,
#  'token[0]=Ohio': 1594,
#  'token[0]=users': 11899,
#  'token[0]=called': 350,
#  'token[0]=Pauli': 1835,
#  'token[0]=slumber': 11678,
#  'token[0]=Share': 10160,
#  'token[0]=round-trip': 11586,
#  'token[0]=leave': 986,
#  'token[0]=wells': 4908,
#  'token[0]=Daoud': 6580,
#  'token[0]=Not': 4432,
#  'token[0]=Peru': 3788,
#  'token[0]=107.0': 8227,
#  'token[0]=Lecce': 6865,
#  'token[0]=Lisa': 9627,
#  'token[0]=RE': 10016,
#  'token[0]=District': 2287,
#  'token[0]=Pauline': 9940,
#  'token[0]=Diplomats': 5181,
#  'token[0]=dead': 1090,
#  'token[0]=kidnap': 11171,
#  'token[0]=laying': 11184,
#  'token[0]=system': 997,
#  'token[0]=Tatran': 10303,
#  'token[0]=CRP': 8958,
#  'token[0]=532-8': 8598,
#  'token[0]=Rome': 2900,
#  'token[0]=fixing': 7580,
#  'token[0]=12.0': 2754,
#  'token[0]=incomprehensible': 11112,
#  'token[0]=Presidential': 9983,
#  'token[0]=recalled': 4809,
#  'token[0]=thousand': 11809,
#  'token[0]=surrounding': 11769,
#  'token[0]=load': 4716,
#  'token[0]=volcano': 8103,
#  'token[0]=Iliescu': 2846,
#  'token[0]=Melanie': 9730,
#  'token[0]=pits': 7814,
#  'token[0]=thrown': 4888,
#  'token[0]=Grossman': 9345,
#  'token[0]=research': 2451,
#  'token[0]=236': 8412,
#  'token[0]=Francis': 5217,
#  'token[0]=partners': 3458,
#  'token[0]=Marco': 2870,
#  'token[0]=ranked': 4804,
#  'token[0]=delegates': 2628,
#  'token[0]=CLEVELAND': 1166,
#  'token[0]=department': 2631,
#  'token[0]=clearing': 7387,
#  'token[0]=Drobnjak': 6607,
#  'token[0]=Gurion': 9353,
#  'token[0]=hampered': 11048,
#  'token[0]=British': 211,
#  'token[0]=359-2-84561': 8494,
#  'token[0]=funding': 7601,
#  'token[0]=Munich': 1243,
#  'token[0]=win': 183,
#  'token[0]=Ata-ur-Rehman': 4229,
#  'token[0]=occurs': 11313,
#  'token[0]=end': 282,
#  'token[0]=budgeted': 7358,
#  'token[0]=President': 163,
#  'token[0]=Sloboda': 10207,
#  'token[0]=Dm': 4286,
#  'token[0]=liner': 7696,
#  'token[0]=responding': 7906,
#  'token[0]=chaos': 5706,
#  'token[0]=Ajax': 673,
#  'token[0]=Martinez': 1507,
#  'token[0]=bone': 5686,
#  'token[0]=Kennedy': 4374,
#  'token[0]=clashed': 10698,
#  'token[0]=bln': 1335,
#  'token[0]=paid': 1360,
#  'token[0]=576': 8604,
#  'token[0]=Division': 1014,
#  'token[0]=Penrose': 5456,
#  'token[0]=Stansted': 1716,
#  'token[0]=sales': 455,
#  'token[0]=Officials': 2328,
#  'token[0]=sending': 4841,
#  'token[0]=prepare': 11430,
#  'token[0]=rainfall': 4070,
#  'token[0]=expensive': 7548,
#  'token[0]=Chonnam': 5141,
#  'token[0]=tasks': 8020,
#  'token[0]=800,000': 5022,
#  'token[0]=DAILY': 9075,
#  'token[0]=.359': 8140,
#  'token[0]=aged': 2945,
#  'token[0]=Kiely': 9545,
#  'token[0]=utility': 11900,
#  'token[0]=glad': 11024,
#  'token[0]=veterans': 11913,
#  'token[0]=2-0': 734,
#  'token[0]=factor': 3967,
#  'token[0]=violent': 3106,
#  'token[0]=AA-': 5030,
#  'token[0]=Soyoil': 2918,
#  'token[0]=compound': 7410,
#  'token[0]=valuing': 11904,
#  'token[0]=conference': 640,
#  'token[0]=scorer': 6050,
#  'token[0]=Linz': 2867,
#  'token[0]=AIRES': 4208,
#  'token[0]=flames': 10985,
#  'token[0]=.542': 4929,
#  'token[0]=Colombian': 3174,
#  'token[0]=Oriente': 5435,
#  'token[0]=Bessemer': 6466,
#  'token[0]=Revised': 7052,
#  'token[0]=ensure': 3379,
#  'token[0]=identify': 11096,
#  'token[0]=ideal': 11095,
#  'token[0]=Osaka': 9884,
#  'token[0]=Goncharova': 9329,
#  'token[0]=Steel': 10241,
#  'token[0]=Pa': 9927,
#  'token[0]=PUNR': 3783,
#  'token[0]=northwestern': 5941,
#  'token[0]=Lloyd': 1127,
#  'token[0]=Finn': 6660,
#  'token[0]=become': 1190,
#  'token[0]=African': 427,
#  'token[0]=3.1': 6303,
#  'token[0]=1915.00': 8330,
#  'token[0]=brawl': 7350,
#  'token[0]=pitched': 4056,
#  'token[0]=Bodies': 8899,
#  'token[0]=protein': 11469,
#  'token[0]=saving': 7925,
#  'token[0]=sleeping': 11672,
#  'token[0]=game': 267,
#  'token[0]=Felicia': 6655,
#  'token[0]=Radka': 10027,
#  'token[0]=SER': 3811,
#  'token[0]=accused': 598,
#  'token[0]=venue': 4900,
#  'token[0]=unworthy': 11885,
#  'token[0]=began': 531,
#  'token[0]=5.': 327,
#  'token[0]=meet': 352,
#  'token[0]=Airways': 2776,
#  'token[0]=9,800': 8672,
#  'token[0]=Muzaffarabad': 9776,
#  'token[0]=37.': 8499,
#  'token[0]=immigrants': 7641,
#  'token[0]=retiring': 6031,
#  'token[0]=Piper': 9971,
#  'token[0]=Alec': 5052,
#  'token[0]=surge': 4122,
#  'token[0]=Nationalist': 6952,
#  'token[0]=exhaustion': 7540,
#  'token[0]=pinch-hitter': 4773,
#  'token[0]=can': 293,
#  'token[0]=Zairean': 10473,
#  'token[0]=raid': 7868,
#  'token[0]=worker': 11964,
#  'token[0]=quite': 2446,
#  'token[0]=As': 1064,
#  'token[0]=Once': 9870,
#  'token[0]=Kabariti': 3225,
#  'token[0]=Bukovec': 8931,
#  'token[0]=seed': 729,
#  'token[0]=Jimmy': 4362,
#  'token[0]=municipality': 11274,
#  'token[0]=shares': 201,
#  'token[0]=word': 4914,
#  'token[0]=Truiden': 7193,
#  'token[0]=notes': 5942,
#  'token[0]=Lada': 9597,
#  'token[0]=Trax': 5582,
#  'token[0]=six': 155,
#  'token[0]=inter-ethnic': 11143,
#  'token[0]=devoted': 10846,
#  'token[0]=done': 1736,
#  'token[0]=MPs': 4399,
#  'token[0]=suburb': 6105,
#  'token[0]=Viktor': 10401,
#  'token[0]=settled': 3500,
#  'token[0]=Jamaica': 2113,
#  'token[0]=common': 1531,
#  'token[0]=athletics': 7309,
#  'token[0]=A': 86,
#  'token[0]=Ekimov': 9176,
#  'token[0]=142': 4958,
#  'token[0]=150': 2072,
#  'token[0]=time-trial': 11822,
#  'token[0]=supporters': 4120,
#  'token[0]=wild-card': 6176,
#  'token[0]=stores': 3091,
#  'token[0]=Teams': 7180,
#  'token[0]=drowned': 10886,
#  'token[0]=European': 229,
#  'token[0]=coached': 5718,
#  'token[0]=Wrexham': 5621,
#  'token[0]=BERLIN': 5078,
#  'token[0]=b': 279,
#  'token[0]=convicted': 1864,
#  'token[0]=finds': 4665,
#  'token[0]=two-thirds': 8066,
#  'token[0]=asylum': 3331,
#  'token[0]=Marble': 5373,
#  'token[0]=Zylstra': 10493,
#  'token[0]=refuelled': 6010,
#  'token[0]=strokes': 6100,
#  'token[0]=Anders': 3598,
#  'token[0]=ends': 2400,
#  'token[0]=singles': 362,
#  'token[0]=Perhaps': 9947,
#  'token[0]=making': 863,
#  'token[0]=restored': 4820,
#  'token[0]=Botham': 3163,
#  'token[0]=Stork': 7148,
#  'token[0]=Fiorentina': 2292,
#  'token[0]=monitor': 11262,
#  'token[0]=416': 4184,
#  'token[0]=spy': 7980,
#  'token[0]=1952': 8336,
#  'token[0]=birth': 5681,
#  'token[0]=arriving': 3887,
#  'token[0]=name': 1207,
#  'token[0]=MTK': 9675,
#  'token[0]=York': 292,
#  'token[0]=Men': 375,
#  'token[0]=Petroleums': 9954,
#  'token[0]=killings': 5890,
#  'token[0]=Rubin': 1323,
#  'token[0]=14-7': 8284,
#  'token[0]=Briton': 4255,
#  'token[0]=primarily': 11441,
#  'token[0]=Victor': 10395,
#  'token[0]=popular': 3464,
#  'token[0]=raft': 11494,
#  'token[0]=La': 2119,
#  'token[0]=Essilor': 9195,
#  'token[0]=Diniz': 6593,
#  'token[0]=painful': 4755,
#  'token[0]=pass': 4764,
#  'token[0]=FFT': 9219,
#  'token[0]=taken': 564,
#  'token[0]=hijack': 11075,
#  'token[0]=negotiations': 1149,
#  'token[0]=White': 615,
#  'token[0]=bizarre': 7334,
#  'token[0]=wars': 8106,
#  'token[0]=Olhovskiy': 9865,
#  'token[0]=Calcutta': 1941,
#  'token[0]=uses': 6157,
#  'token[0]=KTM': 6824,
#  'token[0]=statements': 11724,
#  'token[0]=Dividend': 3663,
#  'token[0]=+3': 2752,
#  'token[0]=SV': 3277,
#  'token[0]=era': 7533,
#  'token[0]=Data': 1808,
#  'token[0]=Palmeiras': 6990,
#  'token[0]=Miriam': 9743,
#  'token[0]=otherwise': 4750,
#  'token[0]=Kongsvinger': 9559,
#  'token[0]=Watson': 7228,
#  'token[0]=city': 398,
#  'token[0]=sexual': 4847,
#  'token[0]=Cowan': 6563,
#  'token[0]=weather': 2066,
#  'token[0]=van': 1378,
#  'token[0]=distance': 3946,
#  'token[0]=mostly': 1641,
#  'token[0]=rapid': 6005,
#  'token[0]=seeding': 846,
#  'token[0]=contained': 5737,
#  'token[0]=Sirnak': 10198,
#  'token[0]=spongiform': 11711,
#  'token[0]=opened': 947,
#  'token[0]=viral': 8096,
#  'token[0]=Endt': 6626,
#  'token[0]=Apertura': 8783,
#  'token[0]=eliminated': 10902,
#  'token[0]=3.98': 8469,
#  'token[0]=reach': 4073,
#  'token[0]=declaring': 7456,
#  'token[0]=excellent': 4652,
#  'token[0]=column': 3356,
#  'token[0]=platinum': 11399,
#  'token[0]=seek': 1465,
#  'token[0]=bid': 1031,
#  'token[0]=plunged': 7818,
#  'token[0]=standards': 7984,
#  'token[0]=0.69': 8177,
#  'token[0]=Haladas': 9375,
#  'token[0]=postponement': 4781,
#  'token[0]=tablets': 8014,
#  'token[0]=Scifo': 7106,
#  'token[0]=Dunajska': 9149,
#  'token[0]=Laasonen': 9593,
#  'token[0]=dominated': 5770,
#  'token[0]=Sarah': 2583,
#  'token[0]=.500': 1667,
#  'token[0]=33.': 8480,
#  'token[0]=rounds': 1368,
#  'token[0]=351': 8489,
#  'token[0]=Q3': 10006,
#  'token[0]=expectations': 2648,
#  'token[0]=Politehnica': 9978,
#  'token[0]=flooding': 10988,
#  'token[0]=DRAWS': 9088,
#  'token[0]=series': 760,
#  'token[0]=holding': 2659,
#  'token[0]=65th': 6355,
#  'token[0]=promoted': 4793,
#  'token[0]=stoppage': 7989,
#  'token[0]=Banking': 8847,
#  'token[0]=analysts': 833,
#  'token[0]=Gail': 9302,
#  'token[0]=Hooper': 6757,
#  'token[0]=stronger': 2063,
#  'token[0]=Denny': 9107,
#  'token[0]=EL': 5190,
#  'token[0]=DAKAR': 9076,
#  'token[0]=healthy': 5853,
#  'token[0]=be': 41,
#  'token[0]=chains': 3913,
#  'token[0]=nursing': 7764,
#  'token[0]=Aa2': 8724,
#  'token[0]=Her': 2844,
#  'token[0]=Dally': 9094,
#  'token[0]=five-run': 4667,
#  'token[0]=staging': 11717,
#  'token[0]=Matthias': 9715,
#  'token[0]=6-2': 190,
#  'token[0]=Larnaca': 3231,
#  'token[0]=Hershiser': 9405,
#  'token[0]=12.3': 8254,
#  'token[0]=alleged': 2160,
#  'token[0]=Gabon': 4318,
#  'token[0]=Oliver': 4440,
#  'token[0]=Barrichello': 5087,
#  'token[0]=projects': 4792,
#  'token[0]=4734': 8568,
#  'token[0]=concert': 7413,
#  'token[0]=luggage': 11219,
#  'token[0]=advancing': 7270,
#  'token[0]=grant': 5841,
#  'token[0]=Food': 9268,
#  'token[0]=Nunthorpe': 9837,
#  'token[0]=FULL': 9228,
#  'token[0]=Sampras': 1510,
#  'token[0]=TUESDAY': 4507,
#  "token[0]=O'Neill": 3774,
#  'token[0]=63rd': 5014,
#  'token[0]=Paes': 9929,
#  'token[0]=Curran': 6570,
#  'token[0]=extended': 3966,
#  'token[0]=Hamas': 3207,
#  'token[0]=blanked': 7338,
#  'token[0]=Father': 9240,
#  'token[0]=prominent': 5990,
#  'token[0]=Mushtaq': 827,
#  'token[0]=Olga': 9864,
#  'token[0]=fresh': 5831,
#  'token[0]=Furyk': 6678,
#  'token[0]=yesterday': 3543,
#  'token[0]=layoffs': 11185,
#  'token[0]=gathered': 4677,
#  'token[0]=interrogated': 11146,
#  'token[0]=Castilla': 5130,
#  'token[0]=prostitutes': 7852,
#  'token[0]=loaded': 4019,
#  'token[0]=bruises': 10644,
#  'token[0]=Jeroen': 6806,
#  'token[0]=Johnny': 3713,
#  'token[0]=Zadar': 7253,
#  'token[0]=Luciano': 9646,
#  'token[0]=Karen': 5311,
#  'token[0]=scattered': 2454,
#  'token[0]=sidelines': 11653,
#  'token[0]=both': 357,
#  'token[0]=branch': 10633,
#  'token[0]=Hutnik': 5266,
#  'token[0]=Citterio': 9020,
#  'token[0]=peaceful': 7800,
#  'token[0]=favourites': 10957,
#  'token[0]=Goulnara': 9334,
#  'token[0]=detailed': 7467,
#  'token[0]=all-rounder': 7280,
#  'token[0]=regional': 11528,
#  'token[0]=58th': 3579,
#  "token[0]='ll": 1221,
#  'token[0]=colonel': 10724,
#  'token[0]=PGA': 9907,
#  'token[0]=FRIENDLY': 4301,
#  'token[0]=supposed': 6111,
#  'token[0]=9-5': 8675,
#  'token[0]=Escort': 4297,
#  'token[0]=T-bill': 7162,
#  'token[0]=Two': 597,
#  'token[0]=hanged': 5849,
#  'token[0]=severely': 7943,
#  'token[0]=constitution': 7423,
#  'token[0]=9-7': 5027,
#  'token[0]=shelled': 11637,
#  'token[0]=Gonzalez': 9330,
#  'token[0]=inside': 2033,
#  'token[0]=motorist': 5928,
#  'token[0]=analyst': 1256,
#  'token[0]=Likud': 6873,
#  'token[0]=Dechy': 9103,
#  'token[0]=Petrovic': 9956,
#  'token[0]=Machines': 6892,
#  'token[0]=wave': 6168,
#  'token[0]=Illness': 9454,
#  'token[0]=Bakker': 6452,
#  'token[0]=thousands': 1913,
#  'token[0]=overhaul': 11344,
#  'token[0]=Voinea': 5599,
#  'token[0]=capital': 271,
#  'token[0]=Amrollah': 8771,
#  'token[0]=these': 629,
#  'token[0]=exit': 5793,
#  'token[0]=respirator': 7905,
#  'token[0]=may': 498,
#  'token[0]=indices': 5871,
#  'token[0]=daily': 806,
#  'token[0]=aviation': 4572,
#  'token[0]=Barcelona': 1484,
#  'token[0]=8.61': 8662,
#  'token[0]=intended': 3999,
#  'token[0]=38.0': 8503,
#  'token[0]=LEEDS': 9586,
#  'token[0]=catch': 3346,
#  'token[0]=3-2': 3572,
#  'token[0]=cross-border': 7442,
#  'token[0]=Parramatta': 5449,
#  'token[0]=GACETA': 9288,
#  'token[0]=TOWN': 7167,
#  'token[0]=AUG': 2770,
#  'token[0]=Yeltsin': 481,
#  'token[0]=Duffy': 5186,
#  'token[0]=pence': 5966,
#  'token[0]=HAMLET': 5249,
#  'token[0]=Arantxa': 2082,
#  'token[0]=Cairo': 4265,
#  'token[0]=Va': 7201,
#  'token[0]=Oliveira': 6971,
#  'token[0]=Abbott': 8729,
#  'token[0]=Salou': 7093,
#  'token[0]=Akbel': 5051,
#  'token[0]=briefing': 3907,
#  'token[0]=Baltimore': 1483,
#  'token[0]=cycling': 2627,
#  'token[0]=Shining': 10172,
#  'token[0]=midnight': 2679,
#  'token[0]=Christchurch': 9016,
#  'token[0]=Inter': 5279,
#  'token[0]=unrest': 1785,
#  'token[0]=quoting': 7865,
#  'token[0]=alongside': 7282,
#  'token[0]=Commercial': 3642,
#  'token[0]=prison': 843,
#  'token[0]=exchanges': 7538,
#  'token[0]=Petrosani': 5458,
#  'token[0]=Dinamo': 4285,
#  'token[0]=getting': 3982,
#  'token[0]=grew': 4684,
#  'token[0]=Before': 5089,
#  ...}

# %%
print(flat_dataset["train"][0]["features"])
tokenizer(flat_dataset["train"][0]["features"])
# Out:
# token[0]=EU first-letter-capitalized
# {'input_ids': [965, 2], 'attention_mask': [1, 1]}

# %%
def encode(examples):
    return tokenizer(examples['features'])

dset_tokenized = flat_dataset.map(encode,batched=True,num_proc=4)

for key,val in dset_tokenized["train"][0].items():
    print(key,":",val)
# Out:
# Map (num_proc=4):   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/46435 [00:00<?, ? examples/s]
# tokens : EU
# pos_tags : 22
# chunk_tags : 11
# ner_tags : 3
# features : token[0]=EU first-letter-capitalized
# input_ids : [965, 2]
# attention_mask : [1, 1]

# %% [markdown]
# # Labels
#
# There are three tasks in this dataset (POS, chunks, NER). So we want to choose one of them and create the "labels" key used by the trainer. So let's pick the POS task.

# %%
def assign_labels(ex):
    return {"labels":ex["pos_tags"]}
dset_tokenized=dset_tokenized.map(assign_labels,batched=True)
# Out:
# Map:   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map:   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map:   0%|          | 0/46435 [00:00<?, ? examples/s]

# %%
dset_tokenized["train"][0]
# Out:
# {'tokens': 'EU',
#  'pos_tags': 22,
#  'chunk_tags': 11,
#  'ner_tags': 3,
#  'features': 'token[0]=EU first-letter-capitalized',
#  'input_ids': [965, 2],
#  'attention_mask': [1, 1],
#  'labels': 22}

# %% [markdown]
# ---
#
# # MLP model
#
# With the data now ready, we'll build the MLP model. Note that this is _identical_ to the MLP model we used for text classification: the only difference between the two applications is in the data.
#
# The model class in its simplest form has `__init__()` which instantiates the layers and `forward()` which implements the actual computation. For more information on these, please see the [PyTorch turorial](https://pytorch.org/tutorials/beginner/introyt/modelsyt_tutorial.html).

# %%
# A Transformers library model wants a config,
# I can simply inherit from the base
# class for pretrained configs
# We don't really need to do anything very special
class MLPConfig(transformers.PretrainedConfig):
    pass

# This is the model
class MLP(transformers.PreTrainedModel):

    config_class=MLPConfig

    # In the initialization method, one instantiates the layers
    # these will be, for the most part the trained parameters of the model
    def __init__(self,config):
        super().__init__(config)
        self.all_tied_weights_keys = {} #Annoying bug in Transformers, must have this here or else we crash on saved model load
        #### HERE WE CREATE THE MODEL'S LAYERS:
        self.vocab_size=config.vocab_size #embedding matrix row count
        # Build and initialize embedding of vocab size x hidden size
        assert tokenizer.vocab["[PAD]"]==0 #let's make sure our assumption of pad==0 holds!

        self.embedding=torch.nn.Embedding(num_embeddings=self.vocab_size,embedding_dim=config.hidden_size,padding_idx=0)
        # Initialize the embeddings to random values
        # Note! This function is relatively clever and keeps the embedding for 0, the padding, pure zeros
        torch.nn.init.uniform_(self.embedding.weight.data,-0.001,0.001) #initialize the embeddings with small random values

        # This takes care of the lower half of the network, now the upper half
        # Output layer: hidden size x output size
        self.output=torch.nn.Linear(in_features=config.hidden_size,out_features=config.nlabels)
        # Now we have the parameters of the model
        self.loss=torch.nn.CrossEntropyLoss() #This loss is meant for classification, so let's use it


    # The computation of the model is put into the forward() function
    # it receives a batch of data and optionally the correct `labels`
    #
    # If given `labels` it returns (loss,output)
    # if not, then it returns (output,)
    def forward(self,input_ids,labels=None,**kwargs):
        #1) sum up the embeddings of the items
        embedded=self.embedding(input_ids) #(batch,ids)->(batch,ids,embedding_dim)
        # Since the Embedding keeps the first row of the matrix pure zeros, we don't need to worry about the padding
        # so next we sum the embeddings across the word dimension
        # (batch,ids,embedding_dim) -> (batch,embedding_dim)
        embedded_summed=torch.sum(embedded,dim=1)

        #2) apply non-linearity
        # (batch,embedding_dim) -> (batch,embedding_dim)
        projected=torch.tanh(embedded_summed) #Note how non-linearity is applied here and not when configuring the layer in __init__()
        # projected=embedded_summed ## If you need to bypass non-linearity, use this :)
        #3) and now apply the upper, output layer of the network
        # (batch,embedding_dim) -> (batch, num_of_classes i.e. 2 in our case)
        logits=self.output(projected)

        # ...and that's all there is to it!

        #print("input_ids.shape",input_ids.shape)
        #print("embedded.shape",embedded.shape)
        #print("embedded_summed.shape",embedded_summed.shape)
        #print("projected.shape",projected.shape)
        #print("logits.shape",logits.shape)

        # If we have labels, we ought to calculate the loss
        if labels is not None:

            # You run it as loss(model_output,correct_labels)
            return (self.loss(logits,labels),logits) #2-tuple, i.e. pair of values returned
        else:
            # No labels, so just return the logits
            return (logits,) #this weird syntax means 1-tuple

# %% [markdown]
# Configure the model

# %%
num_labels = len(POS2ID)

mlp_config = MLPConfig(
    vocab_size=len(tokenizer.vocab),
    hidden_size=20,
    nlabels=num_labels
)

print("mlp_config:", mlp_config)
# Out:
# mlp_config: MLPConfig {
#   "hidden_size": 20,
#   "nlabels": 47,
#   "transformers_version": "5.5.1",
#   "vocab_size": 11985
# }

# %% [markdown]
# ---
#
# # Train the model
#
# We will use the Hugging Face [Trainer](https://huggingface.co/docs/transformers/main_classes/trainer) class for training
#
# * Loads of arguments that control the training
# * Configurable metrics to evaluate performance
# * Data collator builds the batches
# * Early stopping callback stops when eval loss no longer improves
# * Model load/save
# * Good foundation for later deep learning course

# %% [markdown]
# First, let's create a [`TrainingArguments`](https://huggingface.co/docs/transformers/v4.17.0/en/main_classes/trainer#transformers.TrainingArguments) object to specify hyperparameters and various other settings for training.
#
# Printing this simple dataclass object will show not only the values we set, but also the defaults for all other arguments. Don't worry if you don't understand what all of these do! Many are not relevant to us here, and you can find the details in [`Trainer` documentation](https://huggingface.co/docs/transformers/main_classes/trainer) if you are interested.

# %%
trainer_args = transformers.TrainingArguments(
    "mlp_checkpoints", #save checkpoints here
    eval_strategy="steps",
    logging_strategy="steps",
    eval_steps=1000,
    logging_steps=1000,
    save_steps=1000,
    learning_rate=5e-4, #learning rate of the gradient descent
    max_steps=20000,
    load_best_model_at_end=True,
    per_device_train_batch_size=16
)

pprint(trainer_args)
# Out:
# TrainingArguments(
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# average_tokens_across_devices=True,
# batch_eval_metrics=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=False,
# enable_jit_checkpoint=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=1000,
# eval_strategy=IntervalStrategy.STEPS,
# eval_use_gather_object=False,
# fp16=False,
# fp16_full_eval=False,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=False,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=None,
# hub_revision=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_num_input_tokens_seen=no,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=0.0005,
# length_column_name=length,
# liger_kernel_config=None,
# load_best_model_at_end=True,
# local_rank=-1,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=None,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=1000,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs=None,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=20000,
# metric_for_best_model=loss,
# neftune_noise_alpha=None,
# num_train_epochs=3.0,
# optim=OptimizerNames.ADAMW_TORCH_FUSED,
# optim_args=None,
# optim_target_modules=None,
# output_dir=mlp_checkpoints,
# parallelism_config=None,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=16,
# prediction_loss_only=False,
# project=huggingface,
# push_to_hub=False,
# remove_unused_columns=True,
# report_to=[],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=None,
# save_on_each_node=False,
# save_only_model=False,
# save_steps=1000,
# save_strategy=SaveStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# trackio_space_id=trackio,
# train_sampling_strategy=random,
# use_cache=False,
# use_cpu=False,
# use_liger_kernel=False,
# warmup_ratio=None,
# warmup_steps=0,
# weight_decay=0.0,
# )

# %% [markdown]
# Next, let's create a metric for evaluating performance during and after training. We can use the convenience function [`load_metric`](https://huggingface.co/docs/datasets/about_metrics) to load one of many pre-made metrics and wrap this for use by the trainer.
#
# We can use the basic `accuracy` metric, defined as the proportion of correctly predicted labels out of all labels. This time, though, the data is not evenly split.

# %%
import numpy as np
import evaluate

accuracy = evaluate.load("accuracy")

def compute_accuracy(outputs_and_labels):
    outputs, labels = outputs_and_labels
    predictions = np.argmax(outputs, axis=-1) #pick the index of the "winning" label
    return accuracy.compute(predictions=predictions, references=labels)

# %% [markdown]
# We can then create the `Trainer` and train the model by invoking the [`Trainer.train`](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Trainer.train) function.
#
# In addition to the model, the settings passed in through the `TrainingArguments` object created above (`trainer_args`), the data, and the metric defined above, we create and pass the following to the `Trainer`:
#
# * [data collator](https://huggingface.co/docs/transformers/main_classes/data_collator): groups input into batches
# * [`EarlyStoppingCallback`](https://huggingface.co/docs/transformers/main_classes/callback#transformers.EarlyStoppingCallback): stops training when performance stops improving

# %%
# Make a new model
mlp = MLP(mlp_config)


# Argument gives the number of steps of patience before early stopping
# i.e. training is stopped when the evaluation loss fails to improve
# certain number of times
early_stopping = transformers.EarlyStoppingCallback(5)

trainer = transformers.Trainer(
    model=mlp,
    args=trainer_args,
    train_dataset=dset_tokenized["train"],
    eval_dataset=dset_tokenized["validation"].select(range(1000)),
    compute_metrics=compute_accuracy,
    data_collator=transformers.DataCollatorWithPadding(tokenizer),
    callbacks=[early_stopping]
)

trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='20000' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20000/20000 02:31, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>2.983199</td>
#       <td>1.973820</td>
#       <td>0.627000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.852464</td>
#       <td>1.376620</td>
#       <td>0.780000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.445799</td>
#       <td>1.140442</td>
#       <td>0.807000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.209610</td>
#       <td>0.993967</td>
#       <td>0.814000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.067692</td>
#       <td>0.884098</td>
#       <td>0.835000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.960669</td>
#       <td>0.806437</td>
#       <td>0.839000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.853806</td>
#       <td>0.741297</td>
#       <td>0.843000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.778924</td>
#       <td>0.699650</td>
#       <td>0.842000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.740458</td>
#       <td>0.661789</td>
#       <td>0.845000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.690679</td>
#       <td>0.628550</td>
#       <td>0.845000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.660964</td>
#       <td>0.612417</td>
#       <td>0.853000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.632139</td>
#       <td>0.593983</td>
#       <td>0.861000</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.603159</td>
#       <td>0.577978</td>
#       <td>0.868000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.576016</td>
#       <td>0.567529</td>
#       <td>0.869000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.556037</td>
#       <td>0.556067</td>
#       <td>0.870000</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.535909</td>
#       <td>0.550479</td>
#       <td>0.871000</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.535769</td>
#       <td>0.547239</td>
#       <td>0.872000</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.522564</td>
#       <td>0.542052</td>
#       <td>0.873000</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.527808</td>
#       <td>0.539837</td>
#       <td>0.874000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.513378</td>
#       <td>0.538578</td>
#       <td>0.874000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=20000, training_loss=0.9123521270751953, metrics={'train_runtime': 151.407, 'train_samples_per_second': 2113.509, 'train_steps_per_second': 132.094, 'total_flos': 3753724842.0, 'train_loss': 0.9123521270751953, 'epoch': 1.571462245619549})

# %% [markdown]
# That's pretty poor performance for a task as simple as POS tagging where state-of-the-art accuracies are generally 97-99%. (The approach demonstrated in this notebook should be considered more of a teaching tool than a serious tagger implementation.)
#
# However, the result is certainly much better than random, so we can conclude that the model is learning something about the task.

# %% [markdown]
# ---
#
# # What has the model learned?
#
# * The embeddings should have some meaning to them
# * Similar features should have similar embeddings

# %%
# Grab the embedding matrix out of the trained model
# and drop the first row (padding 0)
# then we can treat the embeddings as vectors

weights=mlp.embedding.weight.detach().cpu().numpy()

# %%
import sklearn
qry_idx=tokenizer.vocab["token[0]=in"]
idx2feat={v:k for k,v in tokenizer.vocab.items()}

#calculate the distance of the "in" embedding to all other embeddings
distance_to_qry=sklearn.metrics.pairwise.euclidean_distances(weights[qry_idx:qry_idx+1,:],weights)
nearest_neighbors=np.argsort(distance_to_qry) #indices of words nearest to "in"
for nearest in nearest_neighbors[0,:20]:
    print(idx2feat[nearest])
# Out:
# token[0]=in
# token[0]=after
# token[0]=on
# token[0]=into
# token[0]=under
# token[0]=than
# token[0]=between
# token[0]=In
# token[0]=since
# token[0]=if
# token[0]=by
# token[0]=At
# token[0]=through
# token[0]=during
# token[0]=from
# token[0]=with
# token[0]=before
# token[0]=at
# token[0]=behind
# token[0]=OF

# %% [markdown]
# * The embeddings indeed seem to reflect the task and capture aspects of the meaning of words relevant to the task
# * But now we have many classes, so we should take that into account too
# * We can take the dot-product of the feature embeddings with the output layer weight of the class we care about
# * When you think how the information propagates in the network, this will give us a single number reflecting each feature w.r.t. the selected label
# * Technically speaking, it is the prediction of an example which only has that one feature, with respect to that one class
# * Here is how we can implement it (here we rely on the fact that the model is linear, since we didn't include a nonlinearity earlier in the model's `forward()`

# %%
import numpy

embedding_weights=weights    #shape (features, embedding-dim)
output_weights=mlp.output.weight.detach().cpu().numpy()    #shape (num-labels, embedding-dim)

# We just matrix-multiply these together, since this gives us all the dot-products
weights_by_label=numpy.matmul(numpy.tanh(embedding_weights), output_weights.T)
weights_by_label.shape
# Out:
# (11985, 47)

# %%
def get_most_important_features_for_and_against(label):
    label_idx = POS2ID[label]
    feature_weights = weights_by_label[:,label_idx] #pick the column that interests us

    #The shape of feature_weights is (feature_vocab_size,) i.e. it is a vector
    features_weight_idx = numpy.argsort(-feature_weights) #sort in descending order, this will be vector of indices
    features_for = [idx2feat[feature_idx] for feature_idx in features_weight_idx[:30]]
    features_against = [idx2feat[feature_idx] for feature_idx in features_weight_idx[-30:][::-1]]
    return features_for, features_against

for label in ("DT", "NN", "VB"):
    dt_plus,dt_minus=get_most_important_features_for_and_against(label)
    print(f"{label}: {POS2DESCRIPTION[label]}")
    print(f"Most important features *for* label {label}:")
    pprint("   ".join(dt_plus))
    print()
    print(f"Most important features *against* label {label}:")
    pprint("   ".join(dt_minus))
    print("\n------\n")
# Out:
# DT: Determiner
# Most important features *for* label DT:
# ('token[0]=the   token[0]=a   token[0]=an   token[0]=The   token[0]=this   '
#  'token[0]=some   token[0]=no   token[0]=any   token[0]=A   token[0]="   '
#  'token[0]=both   token[0]=another   token[0]=those   token[0]=This   '
#  'token[0]=all   token[0]=these   token[0]=No   token[0]=An   token[0]=and   '
#  'token[0]=each   token[0]=Some   token[0]=These   token[0]=That   '
#  'token[0]=or   token[0]=that   token[0]=But   token[0]=but   token[0]=All   '
#  'token[0]=THE   token[0]=every')
#
# Most important features *against* label DT:
# ('token[0]=is   token[0]=has   token[0]=he   token[0]=it   token[0]=says   '
#  "token[0]=they   token[0]='s   token[0]=points   token[0]=we   token[0]=she   "
#  'token[0]=him   token[0]=does   token[0]=people   token[0]=I   token[0]=.   '
#  'token[0]=you   token[0]=tonnes   token[0]=them   token[0]=years   '
#  'token[0]=officials   token[0]=He   token[0]=runs   token[0]=It   '
#  'token[0]=talks   token[0]=matches   token[0]=shares   token[0]=seconds   '
#  'token[0]=games   token[0]=metres   token[0]=plans')
#
# ------
#
# NN: Noun, singular or mass
# Most important features *for* label NN:
# ('token[0]=year   token[0]=government   token[0]=percent   token[0]=week   '
#  'token[0]=time   token[0]=company   token[0]=state   token[0]=group   '
#  'token[0]=world   token[0]=day   token[0]=spokesman   token[0]=president   '
#  'token[0]=statement   token[0]=team   token[0]=news   token[0]=division   '
#  'token[0]=peace   token[0]=month   token[0]=party   token[0]=season   '
#  'token[0]=game   token[0]=part   token[0]=market   token[0]=town   '
#  'token[0]=victory   token[0]=soccer   token[0]=capital   token[0]=country   '
#  'token[0]=newsroom   token[0]=league')
#
# Most important features *against* label NN:
# ('token[0]=(   token[0]=$   token[0]=/   token[0]=most   token[0]=which   '
#  "token[0]=when   token[0]=least   token[0]='   token[0]=latest   token[0]=b   "
#  "token[0]=best   token[0]=up   token[0]=There   token[0]=he   token[0]='s   "
#  'token[0]=it   token[0]=where   token[0]=be   token[0]=his   token[0]=out   '
#  'token[0]=have   token[0]=there   token[0]=their   token[0]=they   '
#  'token[0]=its   token[0]=c   token[0]=whose   token[0]=was   '
#  'token[0]=biggest   token[0]=largest')
#
# ------
#
# VB: Verb, base form
# Most important features *for* label VB:
# ('token[0]=be   token[0]=have   token[0]=take   token[0]=$   token[0]=beat   '
#  'token[0]=meet   token[0]=make   token[0]=go   token[0]=do   token[0]=get   '
#  'token[0]=are   token[0]=which   token[0]=give   token[0]=hold   '
#  'token[0]=his   token[0]=see   token[0]=keep   token[0]=say   token[0]=play   '
#  'token[0]=to   token[0]=would   token[0]=their   token[0]=its   '
#  'token[0]=buy   token[0]=want   token[0]=continue   token[0]=help   '
#  'token[0]=stay   token[0]=discuss   token[0]=leave')
#
# Most important features *against* label VB:
# ('token[0]=was   token[0]=-   token[0]=:   token[0]=were   token[0]=said   '
#  'token[0]=--   token[0]=had   token[0]=.   token[0]=did   token[0]=of   '
#  'token[0]=for   token[0]=took   token[0]=told   token[0]=at   token[0]=with   '
#  'token[0]=gave   token[0]=from   token[0]=by   token[0]=added   '
#  'token[0]=fell   token[0]=began   token[0]=In   token[0]=;   token[0]=lost   '
#  'token[0]=after   token[0]=came   token[0]=went   token[0]=reported   '
#  'token[0]=won   token[0]=,')
#
# ------
